# %%
import numpy as np
import matplotlib.pyplot as plt
from PIL import Image

# %%
fname = 'images/mao.jpg'
image = Image.open(fname).convert("L")
arr = np.asarray(image)
plt.imshow(arr, cmap='gray_r')
plt.show()

# %%
row, col = np.shape(image)
print(row, col)
# Out:
# 572 722

# %%
arr
# Out:
# array([[158, 157, 155, ..., 152, 153, 156],
#        [155, 154, 152, ..., 153, 153, 155],
#        [165, 164, 162, ..., 153, 152, 154],
#        ...,
#        [167, 167, 168, ...,  40,  30,  56],
#        [165, 165, 167, ...,  34,  27,  50],
#        [165, 166, 165, ...,  42,  35,  56]], dtype=uint8)

# %%
import cv2

# %%
small = cv2.pyrDown(arr)
small.shape
# Out:
# (286, 361)

# %%
plt.imshow(small)
plt.show()

# %%
me_gray_blur = cv2.bilateralFilter(small,9,75,75)

# %%
plt.imshow(me_gray_blur,cmap='gray')
plt.show()

# %%
me_canny_edges =cv2.Canny(me_gray_blur,10,70)

# %%
plt.imshow(me_canny_edges,cmap='gray_r')
plt.show()

# %%
_,mask = cv2.threshold(me_canny_edges,70,255,cv2.THRESH_BINARY_INV)

# %%
plt.imshow(mask,cmap='gray_r')
plt.show()
