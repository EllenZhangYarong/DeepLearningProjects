# %%
import os
import struct
import numpy as np

import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# # 1 . Create Dataset -- mix mnist training set and test sets together

# %%
def load_data(path, kind=''):
    """Load MNIST data from `path`"""
    labels_path = os.path.join(path,
                               '%s-labels-idx1-ubyte'
                               % kind)
    images_path = os.path.join(path,
                               '%s-images-idx3-ubyte'
                               % kind)
    with open(labels_path, 'rb') as lbpath:
        magic, n = struct.unpack('>II',
                                 lbpath.read(8))
        labels = np.fromfile(lbpath,
                             dtype=np.uint8)

    with open(images_path, 'rb') as imgpath:
        magic, num, rows, cols = struct.unpack('>IIII',
                                               imgpath.read(16))
        images = np.fromfile(imgpath,
                             dtype=np.uint8).reshape(len(labels), 784)

    return images, labels

# %%
path = './datasets/'

# %%
X_train,y_train = load_data(path, kind='train')
X_mnist_test,y_mnist_test = load_data(path, kind='t10k')

# %%
X = X_train
y = y_train

# %% [markdown]
# # 2 . Build Classifier

# %%
from sklearn.ensemble import AdaBoostClassifier
from sklearn.metrics import accuracy_score
from sklearn.tree import DecisionTreeClassifier

# %%
clf_ada = AdaBoostClassifier(
    DecisionTreeClassifier(max_depth=1000),
    n_estimators=6000,
    learning_rate=0.001)

# %% [markdown]
# # 3. Training

# %%
from sklearn.model_selection import KFold
kf = KFold(10, random_state=42, shuffle=True)
hs_scores = []
hs_errors = []
hs_mnist_scores = []
hs_mnist_errors = []

for i in range(30):
    print("----------------%d----------------"%(i+1))
    clf_ada = AdaBoostClassifier(
        DecisionTreeClassifier(max_depth=1000),
        n_estimators=6000,
        learning_rate=0.001)
    
    for train_index, test_index in kf.split(X):
        print("TRAIN:", len(train_index), "TEST:", len(test_index))

        X_train, X_test = X[train_index], X[test_index]
        y_train, y_test = y[train_index], y[test_index]

        clf_ada.fit(X_train,y_train)

        score = clf_ada.score(X_test, y_test)

        hs_scores.append(score)
        hs_errors.append(1-score)

#         print("Accuracy inside fold is %.2f%%"% (score*100))
#         print("Test error inside fold is %.2f%%"% ((1-score)*100))
#         print()
    
    score_mnist = clf_ada.score(X_mnist_test, y_mnist_test)
    hs_mnist_scores.append(score_mnist)
    hs_mnist_errors.append(1-score_mnist)
    print("-----------------------------------------------------")
    print("Accuracy on MNIST test is %.2f%%"% (score_mnist*100))
    print("Test error on MNIST test is %.2f%%"% ((1-score_mnist)*100))
    print("-----------------------------------------------------")
    print()
# Out:
# ----------------1----------------
# TRAIN: 54000 TEST: 6000
# TRAIN: 54000 TEST: 6000
# TRAIN: 54000 TEST: 6000
# TRAIN: 54000 TEST: 6000
# TRAIN: 54000 TEST: 6000
# TRAIN: 54000 TEST: 6000
# TRAIN: 54000 TEST: 6000
# TRAIN: 54000 TEST: 6000
# TRAIN: 54000 TEST: 6000
# TRAIN: 54000 TEST: 6000
# -----------------------------------------------------
# Accuracy on MNIST test is 87.46%
# Test error on MNIST test is 12.54%
# -----------------------------------------------------
#
# ----------------2----------------
# TRAIN: 54000 TEST: 6000
# TRAIN: 54000 TEST: 6000
# TRAIN: 54000 TEST: 6000
# TRAIN: 54000 TEST: 6000
# TRAIN: 54000 TEST: 6000
# TRAIN: 54000 TEST: 6000
# TRAIN: 54000 TEST: 6000
# TRAIN: 54000 TEST: 6000
# TRAIN: 54000 TEST: 6000
# TRAIN: 54000 TEST: 6000
# -----------------------------------------------------
# Accuracy on MNIST test is 87.54%
# Test error on MNIST test is 12.46%
# -----------------------------------------------------
#
# ----------------3----------------
# TRAIN: 54000 TEST: 6000
# TRAIN: 54000 TEST: 6000
# TRAIN: 54000 TEST: 6000
# TRAIN: 54000 TEST: 6000
# TRAIN: 54000 TEST: 6000
# TRAIN: 54000 TEST: 6000
# TRAIN: 54000 TEST: 6000
# TRAIN: 54000 TEST: 6000
# TRAIN: 54000 TEST: 6000
# TRAIN: 54000 TEST: 6000
# -----------------------------------------------------
# Accuracy on MNIST test is 87.44%
# Test error on MNIST test is 12.56%
# -----------------------------------------------------
#
# ----------------4----------------
# TRAIN: 54000 TEST: 6000
# TRAIN: 54000 TEST: 6000
# TRAIN: 54000 TEST: 6000
# TRAIN: 54000 TEST: 6000
# TRAIN: 54000 TEST: 6000
# TRAIN: 54000 TEST: 6000
# TRAIN: 54000 TEST: 6000
# TRAIN: 54000 TEST: 6000
# TRAIN: 54000 TEST: 6000
# TRAIN: 54000 TEST: 6000
# -----------------------------------------------------
# Accuracy on MNIST test is 87.58%
# Test error on MNIST test is 12.42%
# -----------------------------------------------------
#
# ----------------5----------------
# TRAIN: 54000 TEST: 6000
# TRAIN: 54000 TEST: 6000
# TRAIN: 54000 TEST: 6000
# TRAIN: 54000 TEST: 6000
# TRAIN: 54000 TEST: 6000
# TRAIN: 54000 TEST: 6000
# TRAIN: 54000 TEST: 6000
# TRAIN: 54000 TEST: 6000
# TRAIN: 54000 TEST: 6000
# TRAIN: 54000 TEST: 6000
# -----------------------------------------------------
# Accuracy on MNIST test is 87.28%
# Test error on MNIST test is 12.72%
# -----------------------------------------------------
#
# ----------------6----------------
# TRAIN: 54000 TEST: 6000
# TRAIN: 54000 TEST: 6000
# TRAIN: 54000 TEST: 6000
# TRAIN: 54000 TEST: 6000
# TRAIN: 54000 TEST: 6000
# TRAIN: 54000 TEST: 6000
# TRAIN: 54000 TEST: 6000
# TRAIN: 54000 TEST: 6000
# TRAIN: 54000 TEST: 6000
# TRAIN: 54000 TEST: 6000
# -----------------------------------------------------
# Accuracy on MNIST test is 87.24%
# Test error on MNIST test is 12.76%
# -----------------------------------------------------
#
# ----------------7----------------
# TRAIN: 54000 TEST: 6000
# TRAIN: 54000 TEST: 6000
# TRAIN: 54000 TEST: 6000
# TRAIN: 54000 TEST: 6000
# TRAIN: 54000 TEST: 6000
# TRAIN: 54000 TEST: 6000
# TRAIN: 54000 TEST: 6000
# TRAIN: 54000 TEST: 6000
# TRAIN: 54000 TEST: 6000
# TRAIN: 54000 TEST: 6000
# -----------------------------------------------------
# Accuracy on MNIST test is 87.62%
# Test error on MNIST test is 12.38%
# -----------------------------------------------------
#
# ----------------8----------------
# TRAIN: 54000 TEST: 6000
# TRAIN: 54000 TEST: 6000
# TRAIN: 54000 TEST: 6000
# TRAIN: 54000 TEST: 6000
# TRAIN: 54000 TEST: 6000
# TRAIN: 54000 TEST: 6000
# TRAIN: 54000 TEST: 6000
# TRAIN: 54000 TEST: 6000
# TRAIN: 54000 TEST: 6000
# TRAIN: 54000 TEST: 6000
# -----------------------------------------------------
# Accuracy on MNIST test is 87.30%
# Test error on MNIST test is 12.70%
# -----------------------------------------------------
#
# ----------------9----------------
# TRAIN: 54000 TEST: 6000
# TRAIN: 54000 TEST: 6000
# TRAIN: 54000 TEST: 6000
# TRAIN: 54000 TEST: 6000
# TRAIN: 54000 TEST: 6000
# TRAIN: 54000 TEST: 6000
# TRAIN: 54000 TEST: 6000
# TRAIN: 54000 TEST: 6000
# TRAIN: 54000 TEST: 6000
# TRAIN: 54000 TEST: 6000
# -----------------------------------------------------
# Accuracy on MNIST test is 87.52%
# Test error on MNIST test is 12.48%
# -----------------------------------------------------
#
# ----------------10----------------
# TRAIN: 54000 TEST: 6000
# TRAIN: 54000 TEST: 6000
# TRAIN: 54000 TEST: 6000
# TRAIN: 54000 TEST: 6000
# TRAIN: 54000 TEST: 6000
# TRAIN: 54000 TEST: 6000
# TRAIN: 54000 TEST: 6000
# TRAIN: 54000 TEST: 6000
# TRAIN: 54000 TEST: 6000
# TRAIN: 54000 TEST: 6000
# -----------------------------------------------------
# Accuracy on MNIST test is 87.32%
# Test error on MNIST test is 12.68%
# -----------------------------------------------------
#
# ----------------11----------------
# TRAIN: 54000 TEST: 6000
# TRAIN: 54000 TEST: 6000
# TRAIN: 54000 TEST: 6000
# TRAIN: 54000 TEST: 6000
# TRAIN: 54000 TEST: 6000
# TRAIN: 54000 TEST: 6000
# TRAIN: 54000 TEST: 6000
# TRAIN: 54000 TEST: 6000
# TRAIN: 54000 TEST: 6000
# TRAIN: 54000 TEST: 6000
# -----------------------------------------------------
# Accuracy on MNIST test is 87.53%
# Test error on MNIST test is 12.47%
# -----------------------------------------------------
#
# ----------------12----------------
# TRAIN: 54000 TEST: 6000
# TRAIN: 54000 TEST: 6000
# TRAIN: 54000 TEST: 6000
# TRAIN: 54000 TEST: 6000
# TRAIN: 54000 TEST: 6000
# TRAIN: 54000 TEST: 6000
# TRAIN: 54000 TEST: 6000
# TRAIN: 54000 TEST: 6000
# TRAIN: 54000 TEST: 6000
# TRAIN: 54000 TEST: 6000
# -----------------------------------------------------
# Accuracy on MNIST test is 87.60%
# Test error on MNIST test is 12.40%
# -----------------------------------------------------
#
# ----------------13----------------
# TRAIN: 54000 TEST: 6000
# TRAIN: 54000 TEST: 6000
# TRAIN: 54000 TEST: 6000
# TRAIN: 54000 TEST: 6000
# TRAIN: 54000 TEST: 6000
# TRAIN: 54000 TEST: 6000
# TRAIN: 54000 TEST: 6000
# TRAIN: 54000 TEST: 6000
# TRAIN: 54000 TEST: 6000
# TRAIN: 54000 TEST: 6000
# -----------------------------------------------------
# Accuracy on MNIST test is 87.50%
# Test error on MNIST test is 12.50%
# -----------------------------------------------------
#
# ----------------14----------------
# TRAIN: 54000 TEST: 6000
# TRAIN: 54000 TEST: 6000
# TRAIN: 54000 TEST: 6000
# TRAIN: 54000 TEST: 6000
# TRAIN: 54000 TEST: 6000
# TRAIN: 54000 TEST: 6000
# TRAIN: 54000 TEST: 6000
# TRAIN: 54000 TEST: 6000
# TRAIN: 54000 TEST: 6000
# TRAIN: 54000 TEST: 6000
# -----------------------------------------------------
# Accuracy on MNIST test is 87.63%
# Test error on MNIST test is 12.37%
# -----------------------------------------------------
#
# ----------------15----------------
# TRAIN: 54000 TEST: 6000
# TRAIN: 54000 TEST: 6000
# TRAIN: 54000 TEST: 6000
# TRAIN: 54000 TEST: 6000
# TRAIN: 54000 TEST: 6000
# TRAIN: 54000 TEST: 6000
# TRAIN: 54000 TEST: 6000
# TRAIN: 54000 TEST: 6000
# TRAIN: 54000 TEST: 6000
# TRAIN: 54000 TEST: 6000
# -----------------------------------------------------
# Accuracy on MNIST test is 87.26%
# Test error on MNIST test is 12.74%
# -----------------------------------------------------
#
# ----------------16----------------
# TRAIN: 54000 TEST: 6000
# TRAIN: 54000 TEST: 6000
# TRAIN: 54000 TEST: 6000
# TRAIN: 54000 TEST: 6000
# TRAIN: 54000 TEST: 6000
# TRAIN: 54000 TEST: 6000
# TRAIN: 54000 TEST: 6000
# TRAIN: 54000 TEST: 6000
# TRAIN: 54000 TEST: 6000
# TRAIN: 54000 TEST: 6000
# -----------------------------------------------------
# Accuracy on MNIST test is 87.21%
# Test error on MNIST test is 12.79%
# -----------------------------------------------------
#
# ----------------17----------------
# TRAIN: 54000 TEST: 6000
# TRAIN: 54000 TEST: 6000
# TRAIN: 54000 TEST: 6000
# TRAIN: 54000 TEST: 6000
# TRAIN: 54000 TEST: 6000
# TRAIN: 54000 TEST: 6000
# TRAIN: 54000 TEST: 6000
# TRAIN: 54000 TEST: 6000
# TRAIN: 54000 TEST: 6000
# TRAIN: 54000 TEST: 6000
# -----------------------------------------------------
# Accuracy on MNIST test is 87.48%
# Test error on MNIST test is 12.52%
# -----------------------------------------------------
#
# ----------------18----------------
# TRAIN: 54000 TEST: 6000
# TRAIN: 54000 TEST: 6000
# TRAIN: 54000 TEST: 6000
# TRAIN: 54000 TEST: 6000
# TRAIN: 54000 TEST: 6000
# TRAIN: 54000 TEST: 6000
# TRAIN: 54000 TEST: 6000
# TRAIN: 54000 TEST: 6000
# TRAIN: 54000 TEST: 6000
# TRAIN: 54000 TEST: 6000
# -----------------------------------------------------
# Accuracy on MNIST test is 87.47%
# Test error on MNIST test is 12.53%
# -----------------------------------------------------
#
# ----------------19----------------
# TRAIN: 54000 TEST: 6000
# TRAIN: 54000 TEST: 6000
# TRAIN: 54000 TEST: 6000
# TRAIN: 54000 TEST: 6000
# TRAIN: 54000 TEST: 6000
# TRAIN: 54000 TEST: 6000
# TRAIN: 54000 TEST: 6000
# TRAIN: 54000 TEST: 6000
# TRAIN: 54000 TEST: 6000
# TRAIN: 54000 TEST: 6000
# -----------------------------------------------------
# Accuracy on MNIST test is 87.25%
# Test error on MNIST test is 12.75%
# -----------------------------------------------------
#
# ----------------20----------------
# TRAIN: 54000 TEST: 6000
# TRAIN: 54000 TEST: 6000
# TRAIN: 54000 TEST: 6000
# TRAIN: 54000 TEST: 6000
# TRAIN: 54000 TEST: 6000
# TRAIN: 54000 TEST: 6000
# TRAIN: 54000 TEST: 6000
# TRAIN: 54000 TEST: 6000
# TRAIN: 54000 TEST: 6000
# TRAIN: 54000 TEST: 6000
# -----------------------------------------------------
# Accuracy on MNIST test is 87.37%
# Test error on MNIST test is 12.63%
# -----------------------------------------------------
#
# ----------------21----------------
# TRAIN: 54000 TEST: 6000
# TRAIN: 54000 TEST: 6000
# TRAIN: 54000 TEST: 6000
# TRAIN: 54000 TEST: 6000
# TRAIN: 54000 TEST: 6000
# TRAIN: 54000 TEST: 6000
# TRAIN: 54000 TEST: 6000
# TRAIN: 54000 TEST: 6000
# TRAIN: 54000 TEST: 6000
# TRAIN: 54000 TEST: 6000
# -----------------------------------------------------
# Accuracy on MNIST test is 87.59%
# Test error on MNIST test is 12.41%
# -----------------------------------------------------
#
# ----------------22----------------
# TRAIN: 54000 TEST: 6000
# TRAIN: 54000 TEST: 6000
# TRAIN: 54000 TEST: 6000
# TRAIN: 54000 TEST: 6000
# TRAIN: 54000 TEST: 6000
# TRAIN: 54000 TEST: 6000
# TRAIN: 54000 TEST: 6000
# TRAIN: 54000 TEST: 6000
# TRAIN: 54000 TEST: 6000
# TRAIN: 54000 TEST: 6000
# -----------------------------------------------------
# Accuracy on MNIST test is 87.37%
# Test error on MNIST test is 12.63%
# -----------------------------------------------------
#
# ----------------23----------------
# TRAIN: 54000 TEST: 6000
# TRAIN: 54000 TEST: 6000
# TRAIN: 54000 TEST: 6000
# TRAIN: 54000 TEST: 6000
# TRAIN: 54000 TEST: 6000
# TRAIN: 54000 TEST: 6000
# TRAIN: 54000 TEST: 6000
# TRAIN: 54000 TEST: 6000
# TRAIN: 54000 TEST: 6000
# TRAIN: 54000 TEST: 6000
# -----------------------------------------------------
# Accuracy on MNIST test is 87.72%
# Test error on MNIST test is 12.28%
# -----------------------------------------------------
#
# ----------------24----------------
# TRAIN: 54000 TEST: 6000
# TRAIN: 54000 TEST: 6000
# TRAIN: 54000 TEST: 6000
# TRAIN: 54000 TEST: 6000
# TRAIN: 54000 TEST: 6000
# TRAIN: 54000 TEST: 6000
# TRAIN: 54000 TEST: 6000
# TRAIN: 54000 TEST: 6000
# TRAIN: 54000 TEST: 6000
# TRAIN: 54000 TEST: 6000
# -----------------------------------------------------
# Accuracy on MNIST test is 87.51%
# Test error on MNIST test is 12.49%
# -----------------------------------------------------
#
# ----------------25----------------
# TRAIN: 54000 TEST: 6000
# TRAIN: 54000 TEST: 6000
# TRAIN: 54000 TEST: 6000
# TRAIN: 54000 TEST: 6000
# TRAIN: 54000 TEST: 6000
# TRAIN: 54000 TEST: 6000
# TRAIN: 54000 TEST: 6000
# TRAIN: 54000 TEST: 6000
# TRAIN: 54000 TEST: 6000
# TRAIN: 54000 TEST: 6000
# -----------------------------------------------------
# Accuracy on MNIST test is 87.63%
# Test error on MNIST test is 12.37%
# -----------------------------------------------------
#
# ----------------26----------------
# TRAIN: 54000 TEST: 6000
# TRAIN: 54000 TEST: 6000
# TRAIN: 54000 TEST: 6000
# TRAIN: 54000 TEST: 6000
# TRAIN: 54000 TEST: 6000
# TRAIN: 54000 TEST: 6000
# TRAIN: 54000 TEST: 6000
# TRAIN: 54000 TEST: 6000
# TRAIN: 54000 TEST: 6000
# TRAIN: 54000 TEST: 6000
# -----------------------------------------------------
# Accuracy on MNIST test is 87.50%
# Test error on MNIST test is 12.50%
# -----------------------------------------------------
#
# ----------------27----------------
# TRAIN: 54000 TEST: 6000
# TRAIN: 54000 TEST: 6000
# TRAIN: 54000 TEST: 6000
# TRAIN: 54000 TEST: 6000
# TRAIN: 54000 TEST: 6000
# TRAIN: 54000 TEST: 6000
# TRAIN: 54000 TEST: 6000
# TRAIN: 54000 TEST: 6000
# TRAIN: 54000 TEST: 6000
# TRAIN: 54000 TEST: 6000
# -----------------------------------------------------
# Accuracy on MNIST test is 87.51%
# Test error on MNIST test is 12.49%
# -----------------------------------------------------
#
# ----------------28----------------
# TRAIN: 54000 TEST: 6000
# TRAIN: 54000 TEST: 6000
# TRAIN: 54000 TEST: 6000
# TRAIN: 54000 TEST: 6000
# TRAIN: 54000 TEST: 6000
# TRAIN: 54000 TEST: 6000
# TRAIN: 54000 TEST: 6000
# TRAIN: 54000 TEST: 6000
# TRAIN: 54000 TEST: 6000
# TRAIN: 54000 TEST: 6000
# -----------------------------------------------------
# Accuracy on MNIST test is 87.61%
# Test error on MNIST test is 12.39%
# -----------------------------------------------------
#
# ----------------29----------------
# TRAIN: 54000 TEST: 6000
# TRAIN: 54000 TEST: 6000
# TRAIN: 54000 TEST: 6000
# TRAIN: 54000 TEST: 6000
# TRAIN: 54000 TEST: 6000
# TRAIN: 54000 TEST: 6000
# TRAIN: 54000 TEST: 6000
# TRAIN: 54000 TEST: 6000
# TRAIN: 54000 TEST: 6000
# TRAIN: 54000 TEST: 6000
# -----------------------------------------------------
# Accuracy on MNIST test is 87.40%
# Test error on MNIST test is 12.60%
# -----------------------------------------------------
#
# ----------------30----------------
# TRAIN: 54000 TEST: 6000
# TRAIN: 54000 TEST: 6000
# TRAIN: 54000 TEST: 6000
# TRAIN: 54000 TEST: 6000
# TRAIN: 54000 TEST: 6000
# TRAIN: 54000 TEST: 6000
# TRAIN: 54000 TEST: 6000
# TRAIN: 54000 TEST: 6000
# TRAIN: 54000 TEST: 6000
# TRAIN: 54000 TEST: 6000
# -----------------------------------------------------
# Accuracy on MNIST test is 87.16%
# Test error on MNIST test is 12.84%
# -----------------------------------------------------

# %%
hs_mnist_scores
# Out:
# [0.8746,
#  0.8754,
#  0.8744,
#  0.8758,
#  0.8728,
#  0.8724,
#  0.8762,
#  0.873,
#  0.8752,
#  0.8732,
#  0.8753,
#  0.876,
#  0.875,
#  0.8763,
#  0.8726,
#  0.8721,
#  0.8748,
#  0.8747,
#  0.8725,
#  0.8737,
#  0.8759,
#  0.8737,
#  0.8772,
#  0.8751,
#  0.8763,
#  0.875,
#  0.8751,
#  0.8761,
#  0.874,
#  0.8716]

# %%
hs_mnist_errors
# Out:
# [0.12539999999999996,
#  0.12460000000000004,
#  0.12560000000000004,
#  0.12419999999999998,
#  0.12719999999999998,
#  0.12760000000000005,
#  0.12380000000000002,
#  0.127,
#  0.12480000000000002,
#  0.12680000000000002,
#  0.12470000000000003,
#  0.124,
#  0.125,
#  0.12370000000000003,
#  0.12739999999999996,
#  0.1279,
#  0.12519999999999998,
#  0.12529999999999997,
#  0.12749999999999995,
#  0.12629999999999997,
#  0.12409999999999999,
#  0.12629999999999997,
#  0.12280000000000002,
#  0.12490000000000001,
#  0.12370000000000003,
#  0.125,
#  0.12490000000000001,
#  0.12390000000000001,
#  0.126,
#  0.12839999999999996]

# %%
hs_scores
# Out:
# [0.8768333333333334,
#  0.875,
#  0.869,
#  0.8701666666666666,
#  0.8716666666666667,
#  0.8801666666666667,
#  0.869,
#  0.8715,
#  0.873,
#  0.8791666666666667,
#  0.8743333333333333,
#  0.8721666666666666,
#  0.8696666666666667,
#  0.872,
#  0.8726666666666667,
#  0.8796666666666667,
#  0.8716666666666667,
#  0.8748333333333334,
#  0.877,
#  0.876,
#  0.8718333333333333,
#  0.8733333333333333,
#  0.868,
#  0.8721666666666666,
#  0.8683333333333333,
#  0.8778333333333334,
#  0.8701666666666666,
#  0.8696666666666667,
#  0.873,
#  0.8758333333333334,
#  0.8706666666666667,
#  0.8731666666666666,
#  0.8696666666666667,
#  0.871,
#  0.8685,
#  0.8813333333333333,
#  0.8703333333333333,
#  0.8756666666666667,
#  0.87,
#  0.8743333333333333,
#  0.8731666666666666,
#  0.8713333333333333,
#  0.8665,
#  0.8715,
#  0.874,
#  0.8801666666666667,
#  0.8718333333333333,
#  0.8743333333333333,
#  0.8746666666666667,
#  0.8725,
#  0.875,
#  0.8731666666666666,
#  0.8691666666666666,
#  0.8703333333333333,
#  0.8698333333333333,
#  0.8815,
#  0.8725,
#  0.875,
#  0.877,
#  0.8751666666666666,
#  0.8718333333333333,
#  0.8726666666666667,
#  0.869,
#  0.871,
#  0.8716666666666667,
#  0.8793333333333333,
#  0.8695,
#  0.8735,
#  0.8708333333333333,
#  0.8756666666666667,
#  0.8728333333333333,
#  0.8715,
#  0.8711666666666666,
#  0.8688333333333333,
#  0.8733333333333333,
#  0.882,
#  0.8705,
#  0.874,
#  0.8753333333333333,
#  0.8765,
#  0.8738333333333334,
#  0.8691666666666666,
#  0.869,
#  0.8708333333333333,
#  0.8686666666666667,
#  0.8816666666666667,
#  0.8676666666666667,
#  0.8705,
#  0.875,
#  0.8741666666666666,
#  0.8738333333333334,
#  0.8778333333333334,
#  0.8638333333333333,
#  0.8703333333333333,
#  0.8688333333333333,
#  0.8815,
#  0.8718333333333333,
#  0.8703333333333333,
#  0.8731666666666666,
#  0.8771666666666667,
#  0.8728333333333333,
#  0.8731666666666666,
#  0.8678333333333333,
#  0.8708333333333333,
#  0.8711666666666666,
#  0.8795,
#  0.8731666666666666,
#  0.8716666666666667,
#  0.8735,
#  0.8756666666666667,
#  0.8708333333333333,
#  0.8733333333333333,
#  0.8668333333333333,
#  0.8711666666666666,
#  0.8711666666666666,
#  0.8786666666666667,
#  0.8693333333333333,
#  0.8716666666666667,
#  0.874,
#  0.8731666666666666,
#  0.8745,
#  0.8758333333333334,
#  0.8643333333333333,
#  0.8721666666666666,
#  0.8711666666666666,
#  0.8811666666666667,
#  0.8706666666666667,
#  0.8746666666666667,
#  0.8748333333333334,
#  0.8763333333333333,
#  0.8728333333333333,
#  0.8751666666666666,
#  0.8651666666666666,
#  0.8666666666666667,
#  0.874,
#  0.881,
#  0.8726666666666667,
#  0.8713333333333333,
#  0.8733333333333333,
#  0.8753333333333333,
#  0.8748333333333334,
#  0.8748333333333334,
#  0.8703333333333333,
#  0.8693333333333333,
#  0.872,
#  0.8775,
#  0.8696666666666667,
#  0.8713333333333333,
#  0.876,
#  0.8738333333333334,
#  0.8716666666666667,
#  0.8765,
#  0.87,
#  0.871,
#  0.8698333333333333,
#  0.8828333333333334,
#  0.8716666666666667,
#  0.8743333333333333,
#  0.8771666666666667,
#  0.8745,
#  0.8705,
#  0.8743333333333333,
#  0.8665,
#  0.8735,
#  0.869,
#  0.882,
#  0.87,
#  0.8726666666666667,
#  0.8743333333333333,
#  0.876,
#  0.8743333333333333,
#  0.8716666666666667,
#  0.8661666666666666,
#  0.8698333333333333,
#  0.87,
#  0.8811666666666667,
#  0.8721666666666666,
#  0.871,
#  0.877,
#  0.8766666666666667,
#  0.8741666666666666,
#  0.8703333333333333,
#  0.8685,
#  0.8745,
#  0.8698333333333333,
#  0.885,
#  0.8726666666666667,
#  0.8765,
#  0.872,
#  0.877,
#  0.8728333333333333,
#  0.872,
#  0.8658333333333333,
#  0.8713333333333333,
#  0.87,
#  0.8793333333333333,
#  0.8685,
#  0.8703333333333333,
#  0.877,
#  0.8733333333333333,
#  0.8736666666666667,
#  0.873,
#  0.8708333333333333,
#  0.8725,
#  0.8735,
#  0.8796666666666667,
#  0.8676666666666667,
#  0.8751666666666666,
#  0.8735,
#  0.8773333333333333,
#  0.8731666666666666,
#  0.8716666666666667,
#  0.8678333333333333,
#  0.8718333333333333,
#  0.8696666666666667,
#  0.8806666666666667,
#  0.8718333333333333,
#  0.8745,
#  0.8741666666666666,
#  0.877,
#  0.8738333333333334,
#  0.8708333333333333,
#  0.8688333333333333,
#  0.87,
#  0.8713333333333333,
#  0.8788333333333334,
#  0.8723333333333333,
#  0.8716666666666667,
#  0.8785,
#  0.875,
#  0.8723333333333333,
#  0.871,
#  0.8651666666666666,
#  0.874,
#  0.8673333333333333,
#  0.883,
#  0.8671666666666666,
#  0.8725,
#  0.8736666666666667,
#  0.8786666666666667,
#  0.8736666666666667,
#  0.8723333333333333,
#  0.863,
#  0.8723333333333333,
#  0.8731666666666666,
#  0.8791666666666667,
#  0.8695,
#  0.873,
#  0.8768333333333334,
#  0.8738333333333334,
#  0.8728333333333333,
#  0.875,
#  0.8643333333333333,
#  0.8736666666666667,
#  0.8725,
#  0.8805,
#  0.8693333333333333,
#  0.875,
#  0.8756666666666667,
#  0.875,
#  0.8738333333333334,
#  0.877,
#  0.8696666666666667,
#  0.8705,
#  0.8698333333333333,
#  0.877,
#  0.8711666666666666,
#  0.8711666666666666,
#  0.877,
#  0.8755,
#  0.8761666666666666,
#  0.8725,
#  0.8705,
#  0.8718333333333333,
#  0.8705,
#  0.8785,
#  0.8708333333333333,
#  0.8715,
#  0.875,
#  0.8763333333333333,
#  0.8721666666666666,
#  0.8715,
#  0.8668333333333333,
#  0.8716666666666667,
#  0.8743333333333333,
#  0.8785,
#  0.8705,
#  0.8716666666666667,
#  0.8736666666666667,
#  0.8743333333333333,
#  0.8738333333333334,
#  0.8716666666666667,
#  0.8675,
#  0.8731666666666666,
#  0.8711666666666666,
#  0.8775,
#  0.8683333333333333,
#  0.8723333333333333,
#  0.8731666666666666,
#  0.877]

# %%
hs_errors
# Out:
# [0.12316666666666665,
#  0.125,
#  0.131,
#  0.12983333333333336,
#  0.1283333333333333,
#  0.11983333333333335,
#  0.131,
#  0.12849999999999995,
#  0.127,
#  0.12083333333333335,
#  0.1256666666666667,
#  0.12783333333333335,
#  0.1303333333333333,
#  0.128,
#  0.1273333333333333,
#  0.12033333333333329,
#  0.1283333333333333,
#  0.12516666666666665,
#  0.123,
#  0.124,
#  0.12816666666666665,
#  0.1266666666666667,
#  0.132,
#  0.12783333333333335,
#  0.1316666666666667,
#  0.12216666666666665,
#  0.12983333333333336,
#  0.1303333333333333,
#  0.127,
#  0.12416666666666665,
#  0.1293333333333333,
#  0.12683333333333335,
#  0.1303333333333333,
#  0.129,
#  0.13149999999999995,
#  0.1186666666666667,
#  0.1296666666666667,
#  0.1243333333333333,
#  0.13,
#  0.1256666666666667,
#  0.12683333333333335,
#  0.1286666666666667,
#  0.13349999999999995,
#  0.12849999999999995,
#  0.126,
#  0.11983333333333335,
#  0.12816666666666665,
#  0.1256666666666667,
#  0.1253333333333333,
#  0.12749999999999995,
#  0.125,
#  0.12683333333333335,
#  0.13083333333333336,
#  0.1296666666666667,
#  0.13016666666666665,
#  0.11850000000000005,
#  0.12749999999999995,
#  0.125,
#  0.123,
#  0.12483333333333335,
#  0.12816666666666665,
#  0.1273333333333333,
#  0.131,
#  0.129,
#  0.1283333333333333,
#  0.1206666666666667,
#  0.13049999999999995,
#  0.12649999999999995,
#  0.12916666666666665,
#  0.1243333333333333,
#  0.12716666666666665,
#  0.12849999999999995,
#  0.12883333333333336,
#  0.13116666666666665,
#  0.1266666666666667,
#  0.118,
#  0.12949999999999995,
#  0.126,
#  0.1246666666666667,
#  0.12350000000000005,
#  0.12616666666666665,
#  0.13083333333333336,
#  0.131,
#  0.12916666666666665,
#  0.1313333333333333,
#  0.11833333333333329,
#  0.1323333333333333,
#  0.12949999999999995,
#  0.125,
#  0.12583333333333335,
#  0.12616666666666665,
#  0.12216666666666665,
#  0.13616666666666666,
#  0.1296666666666667,
#  0.13116666666666665,
#  0.11850000000000005,
#  0.12816666666666665,
#  0.1296666666666667,
#  0.12683333333333335,
#  0.12283333333333335,
#  0.12716666666666665,
#  0.12683333333333335,
#  0.13216666666666665,
#  0.12916666666666665,
#  0.12883333333333336,
#  0.12050000000000005,
#  0.12683333333333335,
#  0.1283333333333333,
#  0.12649999999999995,
#  0.1243333333333333,
#  0.12916666666666665,
#  0.1266666666666667,
#  0.13316666666666666,
#  0.12883333333333336,
#  0.12883333333333336,
#  0.1213333333333333,
#  0.1306666666666667,
#  0.1283333333333333,
#  0.126,
#  0.12683333333333335,
#  0.12549999999999994,
#  0.12416666666666665,
#  0.1356666666666667,
#  0.12783333333333335,
#  0.12883333333333336,
#  0.11883333333333335,
#  0.1293333333333333,
#  0.1253333333333333,
#  0.12516666666666665,
#  0.1236666666666667,
#  0.12716666666666665,
#  0.12483333333333335,
#  0.13483333333333336,
#  0.1333333333333333,
#  0.126,
#  0.119,
#  0.1273333333333333,
#  0.1286666666666667,
#  0.1266666666666667,
#  0.1246666666666667,
#  0.12516666666666665,
#  0.12516666666666665,
#  0.1296666666666667,
#  0.1306666666666667,
#  0.128,
#  0.12250000000000005,
#  0.1303333333333333,
#  0.1286666666666667,
#  0.124,
#  0.12616666666666665,
#  0.1283333333333333,
#  0.12350000000000005,
#  0.13,
#  0.129,
#  0.13016666666666665,
#  0.11716666666666664,
#  0.1283333333333333,
#  0.1256666666666667,
#  0.12283333333333335,
#  0.12549999999999994,
#  0.12949999999999995,
#  0.1256666666666667,
#  0.13349999999999995,
#  0.12649999999999995,
#  0.131,
#  0.118,
#  0.13,
#  0.1273333333333333,
#  0.1256666666666667,
#  0.124,
#  0.1256666666666667,
#  0.1283333333333333,
#  0.13383333333333336,
#  0.13016666666666665,
#  0.13,
#  0.11883333333333335,
#  0.12783333333333335,
#  0.129,
#  0.123,
#  0.1233333333333333,
#  0.12583333333333335,
#  0.1296666666666667,
#  0.13149999999999995,
#  0.12549999999999994,
#  0.13016666666666665,
#  0.11499999999999999,
#  0.1273333333333333,
#  0.12350000000000005,
#  0.128,
#  0.123,
#  0.12716666666666665,
#  0.128,
#  0.13416666666666666,
#  0.1286666666666667,
#  0.13,
#  0.1206666666666667,
#  0.13149999999999995,
#  0.1296666666666667,
#  0.123,
#  0.1266666666666667,
#  0.1263333333333333,
#  0.127,
#  0.12916666666666665,
#  0.12749999999999995,
#  0.12649999999999995,
#  0.12033333333333329,
#  0.1323333333333333,
#  0.12483333333333335,
#  0.12649999999999995,
#  0.1226666666666667,
#  0.12683333333333335,
#  0.1283333333333333,
#  0.13216666666666665,
#  0.12816666666666665,
#  0.1303333333333333,
#  0.11933333333333329,
#  0.12816666666666665,
#  0.12549999999999994,
#  0.12583333333333335,
#  0.123,
#  0.12616666666666665,
#  0.12916666666666665,
#  0.13116666666666665,
#  0.13,
#  0.1286666666666667,
#  0.12116666666666664,
#  0.1276666666666667,
#  0.1283333333333333,
#  0.12150000000000005,
#  0.125,
#  0.1276666666666667,
#  0.129,
#  0.13483333333333336,
#  0.126,
#  0.1326666666666667,
#  0.11699999999999999,
#  0.13283333333333336,
#  0.12749999999999995,
#  0.1263333333333333,
#  0.1213333333333333,
#  0.1263333333333333,
#  0.1276666666666667,
#  0.137,
#  0.1276666666666667,
#  0.12683333333333335,
#  0.12083333333333335,
#  0.13049999999999995,
#  0.127,
#  0.12316666666666665,
#  0.12616666666666665,
#  0.12716666666666665,
#  0.125,
#  0.1356666666666667,
#  0.1263333333333333,
#  0.12749999999999995,
#  0.11950000000000005,
#  0.1306666666666667,
#  0.125,
#  0.1243333333333333,
#  0.125,
#  0.12616666666666665,
#  0.123,
#  0.1303333333333333,
#  0.12949999999999995,
#  0.13016666666666665,
#  0.123,
#  0.12883333333333336,
#  0.12883333333333336,
#  0.123,
#  0.12450000000000006,
#  0.12383333333333335,
#  0.12749999999999995,
#  0.12949999999999995,
#  0.12816666666666665,
#  0.12949999999999995,
#  0.12150000000000005,
#  0.12916666666666665,
#  0.12849999999999995,
#  0.125,
#  0.1236666666666667,
#  0.12783333333333335,
#  0.12849999999999995,
#  0.13316666666666666,
#  0.1283333333333333,
#  0.1256666666666667,
#  0.12150000000000005,
#  0.12949999999999995,
#  0.1283333333333333,
#  0.1263333333333333,
#  0.1256666666666667,
#  0.12616666666666665,
#  0.1283333333333333,
#  0.13249999999999995,
#  0.12683333333333335,
#  0.12883333333333336,
#  0.12250000000000005,
#  0.1316666666666667,
#  0.1276666666666667,
#  0.12683333333333335,
#  0.123]
